# %% [markdown]
# # Project Name - Exploratory Data Analysis of Amazon Prime videos Content Library

# %% [markdown]
# ## Project Summary

# %% [markdown]
# This project performs Exploratory Data Analysis( EDA ) on the Amazon Prime Video content library to uncover patterns in genres, release years, ratings, and regional distribution. It visualizes key insights, identifies trends, and supports data-driven understanding of platform content strategy.

# %% [markdown]
# ### Objectives :

# %% [markdown]
# 1. Analyze the composition of content
# 2. Explore genre distribution and identify most dominant content categories.
# 3. Study yearly trends in content releases, examine ratings, maturity levels, and audience segmentation.
# 4. Identify top-producing countries contributing to the platform
# 5. Highlight outliers, missing values, and data inconsistencies.

# %% [markdown]
# ### Key steps :

# %% [markdown]
# ##### Data Collection and Cleaning :-
# The project used two datasets containing information about titles and credits for movies and TV shows on Amazon Prime Video. The data was cleaned by handling missing values, removing duplicates, and ensuring data consistency.

# %% [markdown]
# ##### Data Visualization :-
# Various visualization techniques were used including Box plots, Histograms, Bar plots, Scatter plots, Line Plots, Pie charts and violin plots.The visualizations helped uncover patterns and releationships within the data.

# %% [markdown]
# ##### Insights Analysis :-
# This EDA provides valuable information for understanding the landscape of Amazon prime video's content .Content creators, platform startegists, and movie makers, Producers and viewrs can benefit from this analysis for making informed decisions.Futuer research could focus on specific geners, redions or content types for deeper insights.

# %% [markdown]
# ### Let's Begin!

# %% [markdown]
# ##### Introduce Libraries

# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ##### Data importing

# %%
# import csv file 1
data1 = pd.read_csv('credits.csv', encoding= 'unicode_escape')

# %%
# import csv file 2
data2 = pd.read_csv('titles.csv', encoding= 'unicode_escape')

# %%
data1.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
data2.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
data1.shape
# Out:
# (124235, 5)

# %%
data2.shape
# Out:
# (9871, 15)

# %% [markdown]
# ##### Data Merging

# %%
#merge 2 datasets on common column id 
df = pd.merge(data1,data2, on = 'id')

# %%
df.shape
# Out:
# (124347, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   person_id             124347 non-null  int64
#  1   id                    124347 non-null  object
#  2   name                  124347 non-null  object
#  3   character             108040 non-null  object
#  4   role                  124347 non-null  object
#  5   title                 124347 non-null  object
#  6   type                  124347 non-null  object
#  7   description           124256 non-null  object
#  8   release_year          124347 non-null  int64
#  9   age_certification     56707 non-null   object
#  10  runtime               124347 non-null  int64
#  11  genres                124347 non-null  object
#  12  production_countries  124347 non-null  object
#  13  seasons               8153 non-null    float64
# ...

# %%
#print the merged data frame - df
df
# Out:
#         person_id         id           name      character      role  \
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124342    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124343    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124344     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124345    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124346    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
#                     title   type  \
# 0       The Three Stooges   SHOW
# 1       The Three Stooges   SHOW
# 2       The Three Stooges   SHOW
# ...

# %%
df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role', 'title', 'type',
#        'description', 'release_year', 'age_certification', 'runtime', 'genres',
#        'production_countries', 'seasons', 'imdb_id', 'imdb_score',
#        'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# The dataset is related to movies and TV shows available on Amazon Prime Video. It's formed by merging two datasets: titles.csv and credits.csv.
# **title.csv** dataset contains information about movies and TV shows available on Amazon Prime Video. Each row represents a single title.
# **credits.csv** dataset contains information about the people involved in the production of the titles (actors, directors, etc.). Each row represents a person's involvement in a specific title.

# %% [markdown]
# ##### Dataset Columns :-

# %% [markdown]
# - id: Unique identifier for each title.
# - title: Name of the movie or TV show.
# - type: Indicates whether the entry is a MOVIE or a SHOW (TV series).
# - description: Short summary of the title.
# - release_year: Year the title was released.
# - age_certification: Content rating (e.g., PG-13, TV-MA).
# - runtime: Duration in minutes (for movies) or average runtime (for shows).
# - genres: List of genres associated with the title (e.g., ['Comedy', 'Drama']).
# - production_countries: Countries where the title was produced (as a list).
# - seasons: Number of seasons (applicable only for TV shows).
# - imdb_id: Unique IMDb identifier for the title.
# - imdb_score: IMDb rating.
# - imdb_votes: Number of votes the title has received on IMDb.
# - tmdb_popularity: Popularity metric from TMDb (The Movie Database).
# - tmdb_score: TMDb rating score.
# - person_id: Unique identifier for each individual (actor, director, etc.).
# - name: Name of the actor, director, or crew member.
# - character: Character played by the person (only for actors).
# - role: Role in the title (e.g., ACTOR, DIRECTOR).

# %%
df.dtypes
# Out:
# person_id                 int64
# id                       object
# name                     object
# character                object
# role                     object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %% [markdown]
# ## Null values

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# person_id                    0
# id                           0
# name                         0
# character                16307
# role                         0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67640
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116194
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10265
# dtype: int64

# %% [markdown]
# - We have null values in character, age_certification, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score columns.
# Let' drop the null values from these columns

# %% [markdown]
# ##### Clean Null Values

# %%
#replace null values with 'unknown'
df['character'].fillna('unknown',inplace =  True )

# %%
pd.isnull(df).sum()
# Out:
# person_id                    0
# id                           0
# name                         0
# character                    0
# role                         0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67640
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116194
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10265
# dtype: int64

# %%
#drop null values in description column
df.dropna(subset = ['description'], inplace = True)

# %%
#Mode of age_certification
df['age_certification'].mode()[0]
# Out:
# 'R'

# %%
#Replace all null values of age_certification with mode
df['age_certification'].fillna(df['age_certification'].mode()[0], inplace = True)

# %%
pd.isnull(df).sum()
# Out:
# person_id                    0
# id                           0
# name                         0
# character                    0
# role                         0
# title                        0
# type                         0
# description                  0
# release_year                 0
# age_certification            0
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116155
# imdb_id                   5234
# imdb_score                5980
# imdb_votes                6004
# tmdb_popularity             13
# tmdb_score               10239
# dtype: int64

# %%
#relplacing null values in seasons column with 0
df['seasons'].fillna(0, inplace = True)

# %% [markdown]
# The 'seasons' column has null values because it's only applicable to TV shows, Movies don't have seasons so these entries would replace with 0.

# %%
#Since 'imdb_id' is unique for Movies and TV shows, we will drop all null entries in 'imdb_id' columns.
df.dropna(subset = ['imdb_id'], inplace = True)

# %%
round(df['imdb_score'].mean(),1)
# Out:
# np.float64(6.0)

# %%
df['imdb_score'].fillna(round(df['imdb_score'].mean(),1), inplace = True)

# %% [markdown]
# - 'imdb_score' represents the rating of a Movie or TV show, removing null values in 'imdb_score' might lead to data loss it's better to replace them with mean.

# %%
#'imdb_votes' replace the null values with 0.Which counts O.
df['imdb_votes'].fillna(0, inplace = True)

# %%
pd.isnull(df).sum()
# Out:
# person_id                  0
# id                         0
# name                       0
# character                  0
# role                       0
# title                      0
# type                       0
# description                0
# release_year               0
# age_certification          0
# runtime                    0
# genres                     0
# production_countries       0
# seasons                    0
# imdb_id                    0
# imdb_score                 0
# imdb_votes                 0
# tmdb_popularity           13
# tmdb_score              9118
# dtype: int64

# %%
# replace null values in 'tmdb_popularity' column with mean
df['tmdb_popularity'].fillna(round(df['tmdb_popularity'].mean(),2), inplace =True)

# %%
# replace null values in 'tmdb_score' column with mean
df['tmdb_score'].fillna(round(df['tmdb_score'].mean(),1), inplace = True)

# %% [markdown]
# - All the Null values are removed.

# %%
pd.isnull(df).sum()
# Out:
# person_id               0
# id                      0
# name                    0
# character               0
# role                    0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
df.shape
# Out:
# (119022, 19)

# %% [markdown]
# ##### check for duplicate values.

# %%
df.duplicated().sum()
# Out:
# np.int64(168)

# %% [markdown]
# we have 168 duplicates in Datasets.

# %%
#drop all the duplicate values
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Describe

# %%
df.describe()
# Out:
#           person_id   release_year        runtime        seasons  \
# count  1.188540e+05  118854.000000  118854.000000  118854.000000
# mean   3.976869e+05    1995.694592      96.054453       0.153466
# std    5.549632e+05      28.010517      29.798646       1.006917
# min    1.000000e+00    1912.000000       1.000000       0.000000
# 25%    3.821300e+04    1980.000000      83.000000       0.000000
# 50%    1.323810e+05    2009.000000      94.000000       0.000000
# 75%    5.633935e+05    2017.000000     109.000000       0.000000
# max    2.371153e+06    2022.000000     328.000000      49.000000
#
#           imdb_score    imdb_votes  tmdb_popularity     tmdb_score
# count  118854.000000  1.188540e+05    118854.000000  118854.000000
# mean        5.968800  2.312887e+04        10.334860       5.997704
# std         1.238147  8.819975e+04        40.786345       1.252196
# min         1.100000  0.000000e+00         0.000164       0.800000
# ...

# %% [markdown]
# As the dataset is now cleaned and prepared for detailed analysis, the following preprocessing steps were carried out:
#
# 1. **Data Loading and Integration**
#     - The two source files, titles.csv and credits.csv, were imported and combined using the shared key ‘id’ to form a unified dataset
# 2. **Treatment of Missing Values**
#     - Entries with missing values in ‘description’ and ‘imdb_id’ were removed from the dataset.
#     - The ‘age_certification’ field had missing values filled using the mode, ensuring consistency.
#     - Missing values in ‘seasons’, ‘imdb_votes’, and ‘character’ were replaced with 0, 0, and ‘unknown’, respectively.
#     - Columns ‘imdb_score’, ‘tmdb_popularity’, and ‘tmdb_score’ had missing data imputed using their mean values.
# 3. **Duplicate Handling**
#     - Duplicate records were detected and eliminated to maintain data integrity and accuracy.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# Data visualization involves presenting information and data through graphical elements. By using visuals such as charts, graphs, and maps, it helps make complex data easier to understand, allowing users to quickly identify trends, patterns, and outliers.

# %% [markdown]
# - Data analysis is an important process in understanding hidden patterns, relationships and trends within raw information. It forms the foundation of decision-making in almost every domain, from business forecasting to scientific research. Depending on the number of variables under consideration, data analysis can be categorized into three main types: Univariate, Bivariate and Multivariate.

# %% [markdown]
# ### **Univariate**

# %% [markdown]
# Univariate data involves observations consisting of only one variable. The goal is to describe and summarize this single variable’s properties such as its average, spread and shape of distribution. Since there is no relationship or dependency to explore, it is the simplest and most straightforward form of statistical analysis.

# %%
df
# Out:
#         person_id         id           name      character      role  \
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124342    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124343    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124344     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124345    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124346    1938620  tm1054116   Vishwa Bhanu        unknown  DIRECTOR
#
#                     title   type  \
# 0       The Three Stooges   SHOW
# 1       The Three Stooges   SHOW
# 2       The Three Stooges   SHOW
# ...

# %% [markdown]
# #### Bar plot

# %%
a = df.type.value_counts()
a
# Out:
# type
# MOVIE    111454
# SHOW       7400
# Name: count, dtype: int64

# %%
#Bar plot of type
plt.figure(figsize=(10,6))
sns.barplot(x = a.index, y= a.values, width=0.5, color='blue', edgecolor = 'black')
plt.title('Bar plot of type(Movie or TV show)\n', color = 'red')
plt.ylabel('count')
plt.show()

# %% [markdown]
# **Insights**
# - The bar for "Movie" is significantly taller than the bar for "SHOWS", indicating that there are more number of movies than TV shows available on platform.
# - Amazon prime is focousing on Movies over TV shows, this could be because viewer choosing movies over shows.
# - The above information could be valuable for content creators as they can produce, release movies on this platform.

# %%
genre_counts = df['genres'].value_counts()
a = genre_counts[genre_counts>1500]
a
# Out:
# genres
# ['drama']                         8639
# ['comedy']                        5014
# ['drama', 'romance']              2501
# ['horror']                        2050
# ['documentation']                 2027
# ['drama', 'comedy']               1937
# ['comedy', 'drama']               1935
# ['romance', 'comedy']             1622
# ['comedy', 'romance']             1605
# ['thriller', 'crime', 'drama']    1513
# Name: count, dtype: int64

# %%
#Bar plot of genres
plt.figure(figsize = (6,4))
sns.barplot(y = a.index, x = a.values, color = 'green', edgecolor = 'black', orient='h' )
plt.title('Bar plot of genres\n', color = 'red')
plt.xlabel('count')
plt.show()

# %% [markdown]
# **Insights**
#
# - The genre with tallest bars "drama","comedy" are the most common genre on Amazon prime.This also reflects the viewers preferences.
#
# - Although some generes dominate but there are variety of genres available on the platform. This indicates that Amazon prime offers content with diverse taste and preferences.
#
# - The genre distribution can be useful for recommending content to the viewers.

# %%
prod_countries = df['production_countries'].value_counts()
countries = prod_countries[prod_countries >1000]
countries
# Out:
# production_countries
# ['US']          66793
# ['IN']          10625
# ['GB']           6779
# ['CA']           3055
# ['JP']           1917
# []               1795
# ['AU']           1591
# ['FR']           1474
# ['CA', 'US']     1170
# ['GB', 'US']     1101
# Name: count, dtype: int64

# %%
#Bar plot of production countries
plt.figure(figsize=(8,6))
sns.barplot(x = countries.values, y = countries.index, orient='h', color = 'yellow', edgecolor = 'black')
plt.title('Bar plot of production countries\n', color = 'red')
plt.show()

# %% [markdown]
# **Insights**
#
# - The United States has the highest number of productions, indicating that a large portion of Amazon Prime's content is from the US.
#
# - India and United kingdom are the next major contributors to the content library, indicating their significant presence in film and television production.

# %% [markdown]
# #### Histogram

# %%
#Histogram of release_year
plt.figure(figsize = (8,6))
sns.histplot(data = df, x = 'release_year', bins = 20, color = 'skyblue', kde = True)
plt.title('Histogram of release year\n', color = 'red')
plt.show()

# %% [markdown]
# **Insights**
# - The histogram of the release_year column shows the distribution of movies and TV shows across different release years.
# - A large of content on Amazon Prime is released recently that is in last decade. The distribution is skewed towards left.
# - we can see an overall increasing trend in the number of movies or TV shows released over the years. This suggests that Amazon Prime Video's content library has been expanding.

# %%
#Histogram of imdb_score
plt.figure(figsize = (10,8))
sns.histplot(data = df, x = 'imdb_score', bins = 25, color = 'teal', kde = True)
plt.title('Histogram of imdb_score\n', color = 'brown')
plt.show()

# %% [markdown]
# **Insights**
#
# - The histogram shows that the distribution of imdb score is approximately normal.
# - The average imdb score for movies and TV shows on Amazon prime is around 5-7. This suggests that the overall quality of content on the platform is decent.

# %%
# Histogram of runtime
plt.figure(figsize = (8,6))
sns.histplot(data = df, x = 'runtime', bins = 25, color = 'maroon', kde = True)
plt.title('Histogram of runtime\n', color = 'red')
plt.show()

# %% [markdown]
# **Insight**
# - Distribution: The histogram shows that the runtime of movies and TV shows on Amazon Prime is not normally distributed. Instead, it is right-skewed having longer tail on the right side of the peak.
# - The peak of the histogram is around the 70-90 minute. This suggests that the most common runtime for movies or TV shows on Amazon Prime is around 70-90 minutes.
# - There are more number of movies and shows with runtimes between 60 and 100 minutes. This might be the sweet spot for most viewers and creators as it provides a good balance between storytelling and viewer engagement.

# %% [markdown]
# #### Box Plot
#
# Box plots are plotted to visualize the distribution, spread of data and to identify outliers in data.

# %%
# Box plot of imdb_score
plt.figure(figsize = (8,6))
sns.boxplot(data = df, y = 'imdb_score')
plt.title('Box plot of imdb_score\n', color = 'red')
plt.show()

# %% [markdown]
# **Insights**
# - The horizontal line within the box represents the median of imdb_score. This tells us typical rating for movies and TV shows on Amazon prime.
# - Points plotted beyond the lower and upper whiskers are considered as outliers. These represents the movies or TV shows with high or low imdb_score.

# %% [markdown]
# ### **Bivariate**

# %% [markdown]
# Bivariate data refers to a dataset where each observation is associated with two different variables. The goal of analyzing bivariate data is to understand the relationship or association between these two variables. It helps to identify how one variable might affect or be related to the other.

# %% [markdown]
# #### **SCATTER PLOT**
#
# A scatter plot is a type of data visualization that uses dots to represent the values of two numerical variables. Scatter plots are used to observe relationships between variables.

# %%
#Scatter plot of imdb_vote and imdb_scores
sns.scatterplot(data = df, x = 'imdb_votes', y = 'imdb_score', color = 'blue')
plt.title('Scatter plot of imdb_vote and imdb_scores\n', color = 'red')
plt.show()

# %% [markdown]
# **Insights**
# - Positive Correlation: The scatter plot shows a positive correlation between imdb_votes and imdb_score. This means that as the number of votes for a title increases, its IMDb score also tends to increase.
#
# - Positive correlation suggests that titles with more votes are popular and recieves higher ratings.

# %% [markdown]
# #### **LINE PLOT**
#
# Line plot connects data points with a line to show trends over time across continuous variable.

# %%
#line plot of runtime v/s release_year
plt.figure(figsize = (8,6))
sns.lineplot(data = df, y = 'runtime', x = 'release_year')
plt.title('line plot of runtime v/s release_year\n', color = 'red')
plt.show()

# %% [markdown]
# **Insight**
# - There is slight downward trend in average runtime of movies and TV shows over the years. This indicates that Movies and Tv shows are getting shorter.
#
# - In the earlier years movies and TV shows tended to have longer runtimes, but in more recent years the average runtime has decreased.
#
# - This decrease in runtime is because of shorter attention span of viewers, production cost.

# %%
#line plot of imdb_score v/s release_year
plt.figure(figsize = (8,6))
sns.lineplot(data = df, y = 'imdb_score', x = 'release_year')
plt.title('line plot of imdb_score v/s release_year\n', color = 'red')
plt.show()

# %% [markdown]
# **Insights**
#
# - There is slight downward trend in average imdb scores over the years. This suggests that older movies on amazon prime tend to have higher imdb rating compared to newer.
#
# - Several factors could affect the observed trend, such as change in viewers taste, evolving production style and increased competition.

# %% [markdown]
# #### **PIE CHART**
#
# Pie chart is used to visualize the proportions of different categories within a whole dataset. It's circular statistical graph, where each slice of the pie represents a category, and the size of the slice is proportional to the category's contribution to the overall data.

# %%
##Pie chart of type(Movie or TV show)
plt.figure(figsize = (8,6))
plt.pie(df['type'].value_counts(), labels=df['type'].value_counts().index, autopct = '%.2f%%')
plt.title('Pie chart of type(Movie or TV show)\n', color = 'red')
plt.show()

# %% [markdown]
# **Insights**
# - The large size for 'Movies' indicates that Amazon prime primarily focuses on offering a vast collection of movies to it's viewer.
#
# - This information is enough to understand Amazon prime attract viewers who enjoy watching Movies rather than TV series.

# %% [markdown]
# #### **Violin Plot**
#
# A Violin Plot is a statistical chart that combines aspects of a box plot and a kernel density plot to visualize the distribution of a numeric variable across different categories or groups.

# %%
#Violin Plot of imdb_score by type
plt.figure(figsize=(8, 6))
sns.violinplot(x='type', y='imdb_score', data=df)
plt.title('Violin Plot of imdb_score by type')
plt.show()

# %% [markdown]
# **Insights**
#
# - Movies: The distribution of imdb_score for movies shows that higher density of scores is between 6 and 7. This suggests that most movies on Amazon Prime have decent ratings, with a tendency towards higher scores.
#
# - TV Shows: The distribution of imdb_score for TV Shows that higher density of scores is between 7 and 8.
#
# - The median imdb_score for Movies (indicated by the white dot inside the violin) is slightly lower than that of TV Shows. This suggests that, on average, TV shows on Amazon Prime tend to have higher ratings than Movies.

# %% [markdown]
# ### **Multivariate**

# %% [markdown]
# Multivariate data contains three or more variables for each observation. The objective is to uncover how multiple variables interact or jointly affect outcomes. It’s crucial in fields like predictive analytics, econometrics and data science, where relationships are seldom limited to two variables.

# %% [markdown]
# #### **PAIR PLOT**
#
# Pair plot visualizes the pairwise relationship between variables. It includes scatter plots for relationships and histogram or density plots for individual distributions.

# %%
#Pairplot
sns.pairplot(df)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This Exploratory Data Analysis (EDA) of the Amazon Prime Video dataset reveals several meaningful trends that highlight how the platform curates and distributes its content.
#
# - Movies significantly outnumber TV shows, demonstrating Amazon Prime Video’s strong emphasis on film-based content. This suggests a strategy focused on offering a wide variety of quick-watch entertainment options to its global audience.
#
# - Drama and Comedy dominate the genre distribution, indicating audience preference for emotionally engaging and light-hearted narratives. At the same time, the presence of numerous niche genres reflects the platform’s intent to appeal to diverse viewer segments.
#
# - A gradual decline in movie runtimes contrasts with an increase in the number of TV show seasons, hinting at evolving storytelling formats—shorter films for faster consumption and longer series to retain viewer engagement over time.
#
# - Higher ratings for older titles (both IMDb and TMDb) suggest that classic content continues to hold strong appeal. This may stem from nostalgic value, established audience trust, or the higher curation standards applied to older, well-received productions.
#
# - The United States leads content creation, followed by India and the United Kingdom, emphasizing how these regions significantly shape the platform’s global catalog. This distribution also aligns with strong entertainment industries and growing streaming markets in these countries.
#
# Overall, this EDA uncovers clear patterns in content distribution, audience engagement, and rating behavior. These insights can guide content acquisition teams, marketing strategists, data analysts, and creators in making informed decisions about what types of content resonate most. Future analyses—such as sentiment studies, genre-based performance evaluation, or user-behavior prediction—could further deepen understanding and support more effective platform strategies.
